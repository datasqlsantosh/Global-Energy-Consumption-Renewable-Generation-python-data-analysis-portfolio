# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Assuming you have your data stored in a CSV file named 'car_data.csv'
Continent_Consumption = pd.read_csv('/content/sample_data/Continent_Consumption_TWH.csv')
Country_Consumption = pd.read_csv('/content/sample_data/Country_Consumption_TWH.csv')
NonrenewablesTotalPowerGeneration = pd.read_csv('/content/sample_data/nonRenewablesTotalPowerGeneration.csv')
RenewablesTotalPowerGeneration = pd.read_csv('/content/sample_data/renewablesTotalPowerGeneration.csv')
CountriesPowerGeneration = pd.read_csv('/content/sample_data/top20CountriesPowerGeneration.csv')
RenewablePowerGeneration = pd.read_csv('/content/sample_data/renewablePowerGeneration97-17.csv')

print(Continent_Consumption)
print(Country_Consumption)
print(NonrenewablesTotalPowerGeneration)
print(RenewablesTotalPowerGeneration)
print(CountriesPowerGeneration)
print(RenewablePowerGeneration)
# Out:
#     Year      World      OECD     BRICS    Europe  North America  \
# 0   1990  101855.54  52602.49  26621.07  20654.88       24667.23
# 1   1991  102483.56  53207.25  26434.99  20631.62       24841.68
# 2   1992  102588.23  53788.75  25993.05  20189.68       25341.77
# 3   1993  103646.56  54614.48  26283.80  20189.68       25830.23
# 4   1994  104449.03  55579.77  25993.05  20085.01       26365.21
# 5   1995  107112.30  56754.40  26946.71  20713.03       26714.11
# 6   1996  109763.94  58417.49  27481.69  21445.72       27295.61
# 7   1997  110903.68  59022.25  27446.80  21341.05       27574.73
# 8   1998  111450.29  59219.96  27528.21  21503.87       27772.44
# 9   1999  113974.00  60301.55  28319.05  21306.16       28528.39
# 10  2000  116590.75  61685.52  28923.81  21538.76       29342.49
# 11  2001  117521.15  61452.92  29528.57  21934.18       28795.88
# 12  2002  120207.68  61987.90  30552.01  21969.07       29156.41
# ...

# %%
print(Continent_Consumption.head())
print(Country_Consumption.head())
print(NonrenewablesTotalPowerGeneration.head())
print(RenewablesTotalPowerGeneration.head())
print(CountriesPowerGeneration.head())
# Out:
#    Year      World      OECD     BRICS    Europe  North America  \
# 0  1990  101855.54  52602.49  26621.07  20654.88       24667.23
# 1  1991  102483.56  53207.25  26434.99  20631.62       24841.68
# 2  1992  102588.23  53788.75  25993.05  20189.68       25341.77
# 3  1993  103646.56  54614.48  26283.80  20189.68       25830.23
# 4  1994  104449.03  55579.77  25993.05  20085.01       26365.21
#
#    Latin America      Asia  Pacific   Africa  Middle-East       CIS
# 0        5373.06  24574.19  1197.89  4407.77      2581.86  16049.40
# 1        5500.99  24783.53  1186.26  4535.70      2744.68  15898.21
# 2        5628.92  25690.67  1209.52  4582.22      3081.95  14339.79
# 3        5675.44  26876.93  1267.67  4721.78      3349.44  13246.57
# 4        5989.45  28098.08  1279.30  4803.19      3640.19  11606.74
#      Year  China  United States  Brazil  Belgium  Czechia  France  Germany  \
# 0  1990.0  874.0         1910.0   141.0     48.0     50.0   225.0    351.0
# ...

# %%
print(Continent_Consumption.describe())
print(Country_Consumption.describe())
print(NonrenewablesTotalPowerGeneration.describe())
print(RenewablesTotalPowerGeneration.describe())
print(CountriesPowerGeneration.describe())
# Out:
#               Year          World          OECD         BRICS        Europe  \
# count    31.000000      31.000000     31.000000     31.000000     31.000000
# mean   2005.000000  132792.465484  60396.465806  41128.932258  21487.738065
# std       9.092121   22724.116555   3480.622930  13849.968002    899.171139
# min    1990.000000  101855.540000  52602.490000  25993.050000  19643.070000
# 25%    1997.500000  111176.985000  58719.870000  27504.950000  20875.850000
# 50%    2005.000000  133582.180000  61545.960000  38169.660000  21480.610000
# 75%    2012.500000  154853.450000  62360.060000  55521.620000  21951.625000
# max    2020.000000  167553.410000  64883.770000  63255.570000  23108.810000
#
#        North America  Latin America          Asia      Pacific       Africa  \
# count      31.000000      31.000000     31.000000    31.000000    31.000000
# mean    28226.760323    7897.145161  45402.019355  1563.297097  6851.945806
# ...

# %%
# Check for missing values
print(Continent_Consumption.isnull().sum())
# Out:
# Year             0
# World            0
# OECD             0
# BRICS            0
# Europe           0
# North America    0
# Latin America    0
# Asia             0
# Pacific          0
# Africa           0
# Middle-East      0
# CIS              0
# dtype: int64

# %%
print(Country_Consumption.isnull().sum())
# Out:
# Year                    2
# China                   2
# United States           2
# Brazil                  2
# Belgium                 2
# Czechia                 2
# France                  2
# Germany                 2
# Italy                   2
# Netherlands             2
# Poland                  2
# Portugal                2
# Romania                 2
# Spain                   2
# Sweden                  2
# United Kingdom          2
# Norway                  2
# Turkey                  2
# Kazakhstan              2
# Russia                  2
# Ukraine                 2
# Uzbekistan              2
# Argentina               2
# Canada                  2
# Chile                   2
# Colombia                2
# Mexico                  2
# Venezuela               2
# Indonesia               2
# Japan                   2
# Malaysia                2
# South Korea             2
# Taiwan                  2
# Thailand                2
# India                   2
# ...

# %%
print(NonrenewablesTotalPowerGeneration.isnull().sum())
# Out:
# Mode of Generation    0
# Contribution (TWh)    0
# dtype: int64

# %%
print(RenewablesTotalPowerGeneration.isnull().sum())
# Out:
# Mode of Generation    0
# Contribution (TWh)    0
# dtype: int64

# %%
print(CountriesPowerGeneration.isnull().sum())
# Out:
# Country             0
# Hydro(TWh)          0
# Biofuel(TWh)        0
# Solar PV (TWh)      0
# Geothermal (TWh)    0
# Total (TWh)         0
# dtype: int64

# %%
#Pandas tail() method is used to return last n (5 by default) rows of a data frame or series.
print(CountriesPowerGeneration.tail())
# Out:
#         Country  Hydro(TWh)  Biofuel(TWh)  Solar PV (TWh)  Geothermal (TWh)  \
# 15    Indonesia       18.63        0.0006            0.23           12.7600
# 16     Thailand        9.52        1.1000           15.38            0.0001
# 17  South Korea        7.28        2.4600            6.82            0.0000
# 18         Iran       15.05        0.3000            0.02            0.0000
# 19       Taiwan        8.87        1.7300            0.11            0.0000
#
#     Total (TWh)
# 15      41.6406
# 16      30.5401
# 17      25.3200
# 18      15.4500
# 19      12.4000

# %%
#return size dimensions,and shape respectively
print('Continent_Consumption',Continent_Consumption.shape)
print('Country_Consumption',Country_Consumption.shape)
print('NonrenewablesTotalPowerGeneration',NonrenewablesTotalPowerGeneration.shape)
print('RenewablesTotalPowerGeneration',RenewablesTotalPowerGeneration.shape)
print('CountriesPowerGeneration',CountriesPowerGeneration.shape)
# Out:
# Continent_Consumption (31, 12)
# Country_Consumption (33, 45)
# NonrenewablesTotalPowerGeneration (8, 2)
# RenewablesTotalPowerGeneration (9, 2)
# CountriesPowerGeneration (20, 6)

# %%
# Drop a column Total from RenewablesTotalPowerGeneration
RenewablesTotalPowerGeneration = RenewablesTotalPowerGeneration[RenewablesTotalPowerGeneration['Mode of Generation'] != 'Tidal']
print("\nDataFrame after Droping column 'Tidal':")
print(RenewablesTotalPowerGeneration)
# Out:
# DataFrame after Droping column 'Tidal':
#   Mode of Generation  Contribution (TWh)
# 0              Hydro             9863.33
# 1               Wind             5882.82
# 2            Biofuel             2636.03
# 3           Solar PV              841.87
# 4         Geothermal              114.04
# 5    Renewable waste               74.05
# 6      Solar Thermal               36.02
# 8              Total             6384.25

# %%
# Rename the index label 'Total' to 'Tidal'
RenewablesTotalPowerGeneration = RenewablesTotalPowerGeneration.rename(index={'Total': 'Tidal'})

# Display the DataFrame after renaming the index label
print("\nDataFrame after renaming 'Total' to 'Tidal':")
print(RenewablesTotalPowerGeneration)
# Out:
# DataFrame after renaming 'Total' to 'Tidal':
# None

# %%
# Create a bar plot using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Mode of Generation', y='Contribution (TWh)', data=NonrenewablesTotalPowerGeneration , palette='viridis')

# Adding labels and title
plt.xlabel('Mode of Generation')
plt.ylabel('Contribution (TWh)')
plt.title('Contribution of Different Modes of Generation')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-50-5c2214c2490d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Mode of Generation', y='Contribution (TWh)', data=NonrenewablesTotalPowerGeneration , palette='viridis')

# %%
# Create a bar plot using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Mode of Generation', y='Contribution (TWh)', data=RenewablesTotalPowerGeneration  , palette='viridis')

# Adding labels and title
plt.xlabel('Mode of Generation')
plt.ylabel('Contribution (TWh)')
plt.title('Contribution of Different Modes of Generation')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-51-06d798c673ff>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Mode of Generation', y='Contribution (TWh)', data=RenewablesTotalPowerGeneration  , palette='viridis')

# %%
# Create a bar plot using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Country', y='Hydro(TWh)', data=CountriesPowerGeneration , palette='viridis')

# Adding labels and title
plt.xlabel('Country')
plt.ylabel('Hydro(TWh)')
plt.title('Country of most hydrogen')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-53-31c09c1b5d4e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Hydro(TWh)', data=CountriesPowerGeneration , palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Hydro(TWh)', y='Country', data=CountriesPowerGeneration, orient='horizontal', palette='coolwarm')
plt.title('Country of most Hydrogen')
plt.xlabel('Country')
plt.ylabel('Hydro(TWh)')
plt.show()
# Out:
# <ipython-input-55-1eb26fb04aec>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Hydro(TWh)', y='Country', data=CountriesPowerGeneration, orient='horizontal', palette='coolwarm')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Biofuel(TWh)', y='Country', data=CountriesPowerGeneration, orient='horizontal', palette='coolwarm')
plt.title('Country of most Biofuel')
plt.xlabel('Country')
plt.ylabel('Biofuel(TWh)')
plt.show()
# Out:
# <ipython-input-56-ebb7b8d2f393>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Biofuel(TWh)', y='Country', data=CountriesPowerGeneration, orient='horizontal', palette='coolwarm')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Solar PV (TWh)', y='Country', data=CountriesPowerGeneration, orient='horizontal', palette='coolwarm')
plt.title('Country of most Solar PV')
plt.xlabel('Country')
plt.ylabel('Solar PV (TWh)')
plt.show()
# Out:
# <ipython-input-57-a1a17acb9405>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Solar PV (TWh)', y='Country', data=CountriesPowerGeneration, orient='horizontal', palette='coolwarm')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Geothermal (TWh)', y='Country', data=CountriesPowerGeneration, orient='horizontal', palette='coolwarm')
plt.title('Country of most Geothermal')
plt.xlabel('Country')
plt.ylabel('Geothermal (TWh)')
plt.show()
# Out:
# <ipython-input-58-abefe6951c75>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Geothermal (TWh)', y='Country', data=CountriesPowerGeneration, orient='horizontal', palette='coolwarm')

# %%
RenewablePowerGeneration_sorted = RenewablePowerGeneration.sort_values(by='Hydro(TWh)', ascending=False)

# Plotting the sorted data
plt.figure(figsize=(10, 6))
sns.barplot(x='Hydro(TWh)', y='Year', data=RenewablePowerGeneration_sorted, orient='horizontal', palette='coolwarm')
plt.title('Highest Year of Hydrogen')
plt.xlabel('Hydro(TWh)')
plt.ylabel('Year')
plt.show()
# Out:
# <ipython-input-69-99406637f18a>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Hydro(TWh)', y='Year', data=RenewablePowerGeneration_sorted, orient='horizontal', palette='coolwarm')

# %%
RenewablePowerGeneration_sorted = RenewablePowerGeneration.sort_values(by='Solar PV (TWh)', ascending=False)

# Plotting the sorted data
plt.figure(figsize=(10, 6))
sns.barplot(x='Solar PV (TWh)', y='Year', data=RenewablePowerGeneration_sorted, orient='horizontal', palette='coolwarm')
plt.title('Highest Year of Solar PV(TWh)')
plt.xlabel('Solar PV')
plt.ylabel('Year')
plt.show()
# Out:
# <ipython-input-71-82bc32dfac6e>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Solar PV (TWh)', y='Year', data=RenewablePowerGeneration_sorted, orient='horizontal', palette='coolwarm')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Geothermal (TWh)', y='Year', data=RenewablePowerGeneration_sorted, orient='horizontal', palette='coolwarm')
plt.title('Highest Year of Geothermal(TWh)')
plt.xlabel('Geothermal')
plt.ylabel('Year')
plt.show()
# Out:
# <ipython-input-72-6e7923c55e7e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Geothermal (TWh)', y='Year', data=RenewablePowerGeneration_sorted, orient='horizontal', palette='coolwarm')

# %%
RenewablePowerGeneration_sorted = RenewablePowerGeneration.sort_values(by='Biofuel(TWh)', ascending=False)

# Plotting the sorted data
plt.figure(figsize=(10, 6))
sns.barplot(x='Biofuel(TWh)', y='Year', data=RenewablePowerGeneration_sorted, orient='horizontal', palette='coolwarm')
plt.title('Highest Year of Biofuel(TWh)')
plt.xlabel('Biofuel')
plt.ylabel('Year')
plt.show()
# Out:
# <ipython-input-70-6d7bc6584ed5>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Biofuel(TWh)', y='Year', data=RenewablePowerGeneration_sorted, orient='horizontal', palette='coolwarm')

# %%
# Assuming RenewablePowerGeneration is your DataFrame
column_sum = RenewablePowerGeneration['Hydro(TWh)'].sum()

print("Sum of 'Hydro(TWh)':", column_sum)
# Out:
# Sum of 'Hydro(TWh)': 83276.68999999999

# %%
# Sum of Global Energy Consumption
World = Continent_Consumption['World'].sum()
OECD = Continent_Consumption['OECD'].sum()
BRICS = Continent_Consumption['BRICS'].sum()
Europe = Continent_Consumption['Europe'].sum()
North_America = Continent_Consumption['North America'].sum()
Latin_America = Continent_Consumption['Latin America'].sum()
Asia = Continent_Consumption['Asia'].sum()
Pacific = Continent_Consumption['Pacific'].sum()
Africa = Continent_Consumption['Africa'].sum()
Middle_East = Continent_Consumption['Middle-East'].sum()
CIS = Continent_Consumption['CIS'].sum()


print("Sum of 'World':", World)
print("Sum of 'OECD':", OECD)
print("Sum of 'BRICS':", BRICS)
print("Sum of 'Europe':", Europe)
print("Sum of 'North_America':", North_America)
print("Sum of 'Latin_America':", Latin_America)
print("Sum of 'Asia':", Asia)
print("Sum of 'Pacific':", Pacific)
print("Sum of 'Africa':", Africa)
print("Sum of 'Middle_East':", Middle_East)
print("Sum of 'CIS':", CIS)
# Out:
# Sum of 'World': 4116566.430000001
# Sum of 'OECD': 1872290.4400000002
# Sum of 'BRICS': 1274996.9000000001
# Sum of 'Europe': 666119.88
# Sum of 'North_America': 875029.5700000001
# Sum of 'Latin_America': 244811.50000000003
# Sum of 'Asia': 1407462.6
# Sum of 'Pacific': 48462.21000000001
# Sum of 'Africa': 212410.32
# Sum of 'Middle_East': 185510.13
# Sum of 'CIS': 366542.7100000001

# %%
Continent_Consumption_sorted = Continent_Consumption.sort_values(by='World', ascending=False)

# Plotting the sorted data
plt.figure(figsize=(10, 6))
sns.barplot(x='World', y='Year', data=Continent_Consumption_sorted, orient='horizontal', palette='coolwarm')
plt.title('Highest Year of World Energy Consumption')
plt.xlabel('World')
plt.ylabel('Year')
plt.show()
# Out:
# <ipython-input-81-81e75b0d940b>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='World', y='Year', data=Continent_Consumption_sorted, orient='horizontal', palette='coolwarm')

# %%
# Plotting the sorted data
plt.figure(figsize=(10, 6))
sns.barplot(x='OECD', y='Year', data=Continent_Consumption, orient='horizontal', palette='coolwarm')
plt.title('Highest Year of OECD Energy Consumption')
plt.xlabel('OECD')
plt.ylabel('Year')
plt.show()
# Out:
# <ipython-input-82-bc4634773388>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='OECD', y='Year', data=Continent_Consumption_sorted, orient='horizontal', palette='coolwarm')

# %%
# Plotting the sorted data
plt.figure(figsize=(10, 6))
sns.barplot(x='BRICS', y='Year', data=Continent_Consumption, orient='horizontal', palette='coolwarm')
plt.title('Highest Year of BRICS Energy Consumption')
plt.xlabel('BRICS')
plt.ylabel('Year')
plt.show()
# Out:
# <ipython-input-88-d9f00f037e35>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='BRICS', y='Year', data=Continent_Consumption, orient='horizontal', palette='coolwarm')

# %%
# Plotting the sorted data
plt.figure(figsize=(10, 6))
sns.barplot(x='Europe', y='Year', data=Continent_Consumption, orient='horizontal', palette='coolwarm')
plt.title('Highest Year of Europe Energy Consumption')
plt.xlabel('Europe')
plt.ylabel('Year')
plt.show()
# Out:
# <ipython-input-89-e1b5b1ec6220>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Europe', y='Year', data=Continent_Consumption, orient='horizontal', palette='coolwarm')

# %%
# Plotting the sorted data
plt.figure(figsize=(10, 6))
sns.barplot(x='North America', y='Year', data=Continent_Consumption, orient='horizontal', palette='coolwarm')
plt.title('Highest Year of North_America Energy Consumption')
plt.xlabel('North America')
plt.ylabel('Year')
plt.show()
# Out:
# <ipython-input-91-e7d2b5f0eaf4>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='North America', y='Year', data=Continent_Consumption, orient='horizontal', palette='coolwarm')

# %%
# Plotting using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Latin America', y='Year', data=Continent_Consumption, orient='horizontal' ,palette='viridis')

# Adding labels and title
plt.xlabel('Latin America')
plt.ylabel('Year')
plt.title('Energy Consumption Latin America Region in 1990')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-96-e21cb145ca16>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Latin America', y='Year', data=Continent_Consumption, orient='horizontal' ,palette='viridis')

# %%
# Bar plot for Energy by Region
plt.bar(Continent_Consumption.columns[2:], Continent_Consumption.values[0][2:], color='skyblue')
plt.title('Energy by Region in 1990')
plt.xlabel('Region')
plt.ylabel('Energy')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Line plot for Energy Production Trends
plt.plot(CountriesPowerGeneration['Country'], CountriesPowerGeneration['Hydro(TWh)'], marker='o', label='Hydro(TWh)')
plt.plot(CountriesPowerGeneration['Country'], CountriesPowerGeneration['Biofuel(TWh)'], marker='o', label='Biofuel(TWh)')
plt.plot(CountriesPowerGeneration['Country'], CountriesPowerGeneration['Solar PV (TWh)'], marker='o', label='Solar PV (TWh)')
plt.plot(CountriesPowerGeneration['Country'], CountriesPowerGeneration['Geothermal (TWh)'], marker='o', label='Geothermal (TWh)')

plt.title('Energy Production by Country')
plt.xlabel('Country')
plt.ylabel('Energy Production (TWh)')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Area Plot
CountriesPowerGeneration.plot.area(x='Country', y=['Hydro(TWh)', 'Biofuel(TWh)', 'Solar PV (TWh)', 'Geothermal (TWh)'])
plt.title('Energy Consumption')
plt.xlabel('Country')
plt.ylabel('Energy Consumption')
plt.show()
